# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenhastings/HyperParameterTuningForms/blob/main/Parameter_Grid_Forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datasets

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import (load_iris,
                              load_diabetes,
                              load_digits,
                              load_wine)

# %% [markdown]
# ### Scikit-Learn Toy Datasets

# %%
#@title Sklearn Datasets { run: "auto", vertical-output: true, display-mode: "form" }
data = wine #@param ["iris", "diabetes", "digits", "wine"] {type:"raw", allow-input: true}
iris = load_iris()
diabetes = load_diabetes()
digits = load_digits()
wine = load_wine()

iris = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                    columns= iris['feature_names'] + ['target'])

diabetes = pd.DataFrame(data= np.c_[diabetes['data'], diabetes['target']],
                        columns= diabetes['feature_names'] + ['target'])

digits = pd.DataFrame(data= np.c_[digits['data'], digits['target']],
                        columns= digits['feature_names'] + ['target'])

wine = pd.DataFrame(data= np.c_[wine['data'], wine['target']],
                        columns= wine['feature_names'] + ['target'])

sklearn_df = data

sklearn_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
#@title Seaborn Datasets { run: "auto", vertical-output: true, display-mode: "form" }
dataset = "planets" #@param ["anagrams", "anscombe", "attention", "brain_networks", "car_crashes", "diamonds", "dots", "dowjones", "exercise", "flights", "fmri", "geyser", "glue", "healthexp", "iris", "mpg", "penguins", "planets", "seaice", "taxis", "tips", "titanic", "", "", ""] {allow-input: true}

df = sns.load_dataset(dataset)

df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Model Parameters

# %% [markdown]
# * Create Interactive Forms for Hyper-Parameter-Tuning
# * Forms should include all parameters for each model
# * Forms should be general enough for all use cases
# * Use these forms in place of your *param_grid*

# %% [markdown]
# # [Logistic Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %% [markdown]
# - penalty
#  - {‘l1’, ‘l2’, ‘elasticnet’, ‘none’}, default=’l2’
#
# - dual
#  - bool, default=False
# - tol
#  - float, default=1e-4
# - C
#  - float, default=1.0
# - fit_intercept
#  - bool, default=True
# - intercept_scaling
#  - float, default=1
# - class_weight
#  - dict or ‘balanced’, default=None
# - random_state
#  - int, RandomState instance, default=None
# - solver
#  - {‘newton-cg’, ‘lbfgs’, ‘liblinear’, ‘sag’, ‘saga’}, default=’lbfgs’
# - max_iter
#  - int, default=100
# - multi_class
#  - {‘auto’, ‘ovr’, ‘multinomial’}, default=’auto’
# - verbose
#  - int, default=0
# - warm_start
#  - warm_startbool, default=False
# - n_jobs
#  - int, default=None
# - l1_ratio
#  - float, default=None

# %%
#@title LogisticRegression ParamGrid { run: "auto", display-mode: "form" }
penalty = "l1" #@param ["l1", "l2", "elasticnet", "none"]
penalty_2 = "l2" #@param ["l1", "l2", "elasticnet", "none"]
penalty_3 = "elasticnet" #@param ["l1", "l2", "elasticnet", "none"]
penalty_4 = "none" #@param ["l1", "l2", "elasticnet", "none"]
dual = True #@param ["True", "False"] {type:"raw", allow-input: true}
dual_2 = False #@param ["True", "False"] {type:"raw", allow-input: true}
tolerance = 0.0001 #@param {type:"slider", min:0.0001, max:0.1, step:0.0001}
tolerance_2 = 0.0451 #@param {type:"slider", min:0.0001, max:0.1, step:0.0001}
tolerance_3 = 0.0898 #@param {type:"slider", min:0.0001, max:0.1, step:0.0001}
C = 0 #@param {type:"slider", min:0, max:5, step:0.1}
C2 = 2 #@param {type:"slider", min:0, max:5, step:0.1}
C3 = 3.6 #@param {type:"slider", min:0, max:5, step:0.1}
fit_intercept = True #@param ["True", "False"] {type:"raw", allow-input: true}
fit_intercept_2 = False #@param ["True", "False"] {type:"raw", allow-input: true}
intercept_scaling = 0.1 #@param {type:"slider", min:0, max:5, step:0.1}
intercept_scaling_2 = 2.4 #@param {type:"slider", min:0, max:5, step:0.1}
intercept_scaling_3 = 4.6 #@param {type:"slider", min:0, max:5, step:0.1}
class_weight = "None" #@param ["balanced", "None"] {allow-input: true}
class_weight_2 = "balanced" #@param ["balanced", "None"] {allow-input: true}
random_state = 344 #@param {type:"slider", min:0, max:1000, step:1}
solver = "newton-cg" #@param ["newton-cg", "lbfgs", "liblinear", "sag", "saga"] {allow-input: true}
solver2 = "lbfgs" #@param ["newton-cg", "lbfgs", "liblinear", "sag", "saga"] {allow-input: true}
solver3 = "liblinear" #@param ["newton-cg", "lbfgs", "liblinear", "sag", "saga"] {allow-input: true}
solver4 = "sag" #@param ["newton-cg", "lbfgs", "liblinear", "sag", "saga"] {allow-input: true}
solver5 = "saga" #@param ["newton-cg", "lbfgs", "liblinear", "sag", "saga"] {allow-input: true}
max_iter = 1 #@param {type:"slider", min:1, max:1000, step:1}
max_iter2 = 1 #@param {type:"slider", min:1, max:1000, step:1}
max_iter3 = 1 #@param {type:"slider", min:1, max:1000, step:1}
multi_class = "auto" #@param ["auto", "ovr", "multinomial"] {allow-input: true}
multi_class2 = "ovr" #@param ["auto", "ovr", "multinomial"] {allow-input: true}
multi_class3 = "multinomial" #@param ["auto", "ovr", "multinomial"] {allow-input: true}
verbose = 0 #@param {type:"slider", min:0, max:10, step:1}
warm_start = True #@param ["True", "False"] {type:"raw", allow-input: true}
warm_start2 = False #@param ["True", "False"] {type:"raw", allow-input: true}
n_jobs = -2 #@param {type:"slider", min:-2, max:16, step:1}
l1_ratio = 0.014 #@param {type:"slider", min:0, max:1, step:0.001}
l1_ratio2 = 0.493 #@param {type:"slider", min:0, max:1, step:0.001}
l1_ratio3 = 0.954 #@param {type:"slider", min:0, max:1, step:0.001}

clf_param_grid = {
    'penalty': [penalty, penalty_2, penalty_3, penalty_4],
    'dual': [dual, dual_2],
    'tol': [tolerance, tolerance_2, tolerance_3],
    'C': [C, C2, C3],
    'fit_intercept': [fit_intercept, fit_intercept_2],
    'intercept_scaling': [intercept_scaling, intercept_scaling_2, intercept_scaling_3],
    'class_weight': [class_weight, class_weight_2],
    'solver': [solver, solver2, solver3, solver4, solver5],
    'max_iter': [max_iter, max_iter2, max_iter3],
    'multi_class': [multi_class, multi_class2, multi_class3],
    'warm_start': [warm_start, warm_start2],
    'l1_ratio': [l1_ratio, l1_ratio2, l1_ratio3],
    }

clf_search = GridSearchCV(clf, clf_param_grid)

clf_search.fit(X_train, y_train)

clf_search.best_params_

# %% [markdown]
# # [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)

# %% [markdown]
# - criterion
#  -
# - splitter
#  -
# - max_depth
#  -
# - min_samples_split
#  -
# - min_samples_leaf
#  -
# - min_weight_fraction_leaf
#  -
# - max_features
#  -
# - random_state
#  -
# - max_leaf_nodes
#  -
# - min_impurity_decrease
#  -
# - class_weight
#  -
# - ccp_alpha
#  -

# %% [markdown]
# # [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %% [markdown]
# - n_estimators
#  -
# - criterion
#  -
# - max_depth
#  -
# - min_samples_split
#  -
# - min_samples_leaf
#  -
# - min_weight_fraction_leaf
#  -
# - max_features
#  -
# - max_leaf_nodes
#  -
# - min_impurity_decrease
#  -
# - bootstrap
#  -
# - oob_score
#  -
# - n_jobs
#  -
# - random_state
#  -
# - verbose
#  -
# - warm_start
#  -
# - class_weight
#  -
# - ccp_alpha
#  -
# - max_samples
#  -
